# %%
# Load DataSet
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv(r"C:\Users\DHRUV PATEL\Dhruv\dhruv\Dataset\housing_data.csv")

# %%
data.head()
# Out:
#    Unnamed: 0 MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0           0       SC60       RL           65     8450   Pave   NaN      Reg
# 1           1       SC20       RL           80     9600   Pave   NaN      Reg
# 2           2       SC60       RL           68    11250   Pave   NaN      IR1
# 3           3       SC70       RL           60     9550   Pave   NaN      IR1
# 4           4       SC60       RL           84    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0     No    No          No       0    Feb
# 1         Lvl    AllPub  ...        0     No    No          No       0    May
# 2         Lvl    AllPub  ...        0     No    No          No       0    Sep
# 3         Lvl    AllPub  ...        0     No    No          No       0    Feb
# 4         Lvl    AllPub  ...        0     No    No          No       0    Dec
#
# ...

# %%
categorical_columns = data.select_dtypes(include=['object', 'category']).columns.tolist()

print("Categorical columns:", categorical_columns)
# Out:
# Categorical columns: ['MSSubClass', 'MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual', 'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature', 'MoSold', 'SaleType', 'SaleCondition']

# %%
numerical_columns = data.select_dtypes(include=['number']).columns

print("Numerical columns:", numerical_columns)
# Out:
# Numerical columns: Index(['Unnamed: 0', 'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond',
#        'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2',
#        'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces',
#        'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal',
#        'YrSold', 'SalePrice'],
#       dtype='object')

# %%
data.drop(['Unnamed: 0','Alley', 'MasVnrType', 'Electrical', 'GarageYrBlt'],axis='columns')
# Out:
#      MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0          SC60       RL           65     8450   Pave      Reg         Lvl
# 1          SC20       RL           80     9600   Pave      Reg         Lvl
# 2          SC60       RL           68    11250   Pave      IR1         Lvl
# 3          SC70       RL           60     9550   Pave      IR1         Lvl
# 4          SC60       RL           84    14260   Pave      IR1         Lvl
# ...         ...      ...          ...      ...    ...      ...         ...
# 1455       SC60       RL           62     7917   Pave      Reg         Lvl
# 1456       SC20       RL           85    13175   Pave      Reg         Lvl
# 1457       SC70       RL           66     9042   Pave      Reg         Lvl
# 1458       SC20       RL           68     9717   Pave      Reg         Lvl
# 1459       SC20       RL           75     9937   Pave      Reg         Lvl
#
# ...

# %%
data.isnull().sum()
# Out:
# Unnamed: 0       0
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
#                 ..
# MoSold           0
# YrSold           0
# SaleType         0
# SaleCondition    0
# SalePrice        0
# Length: 81, dtype: int64

# %%
data.shape
# Out:
# (1460, 81)

# %% [markdown]
# ### Feature Engineering

# %%
# add new collumns from existing collumns

# %%
data['House']=data['SalePrice'] - data['LotArea']

# %%
data.head()
# Out:
#    Unnamed: 0 MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0           0       SC60       RL           65     8450   Pave   NaN      Reg
# 1           1       SC20       RL           80     9600   Pave   NaN      Reg
# 2           2       SC60       RL           68    11250   Pave   NaN      IR1
# 3           3       SC70       RL           60     9550   Pave   NaN      IR1
# 4           4       SC60       RL           84    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolQC Fence MiscFeature MiscVal MoSold YrSold  \
# 0         Lvl    AllPub  ...     No    No          No       0    Feb   2008
# 1         Lvl    AllPub  ...     No    No          No       0    May   2007
# 2         Lvl    AllPub  ...     No    No          No       0    Sep   2008
# 3         Lvl    AllPub  ...     No    No          No       0    Feb   2006
# 4         Lvl    AllPub  ...     No    No          No       0    Dec   2008
#
# ...

# %%
data.shape      #(rows , columns)
# Out:
# (1460, 82)

# %% [markdown]
# ## Scatter Plot

# %%
plt.scatter(x='SalePrice',y='House',data=data)
plt.title("Relationship between SalePrice and House")
plt.xlabel('Sale Price')
plt.ylabel('House')
plt.show()

# Insights 
#>> we have see that linear relationship with increase sale price with House

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea',
#        'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
# ...

# %%
### Calculate total area & price per sqr ft
data['TotalUsableArea']=data['GrLivArea']+data['TotalBsmtSF']+data['GarageArea']
data['PricePerTotalSqrFt']=data['SalePrice']/data['TotalUsableArea']

# %%
data.sample(5)
# Out:
#       Unnamed: 0 MSSubClass MSZoning  LotFrontage  LotArea Street Alley  \
# 728          728       SC90       RL           85    11475   Pave   NaN
# 497          497       SC50       RL           60     9120   Pave  Pave
# 379          379       SC60       RL           60     8123   Pave   NaN
# 514          514       SC45       RL           55    10594   Pave   NaN
# 1383        1383       SC30       RL            0    25339   Pave   NaN
#
#      LotShape LandContour Utilities  ... MiscFeature MiscVal MoSold YrSold  \
# 728       Reg         Lvl    AllPub  ...          No       0    Jul   2009
# 497       Reg         Lvl    AllPub  ...          No       0    Jun   2008
# 379       IR1         Lvl    AllPub  ...          No       0    Jun   2009
# 514       Reg         Lvl    AllPub  ...          No       0    Jun   2007
# 1383      Reg         Lvl    AllPub  ...          No       0    Aug   2007
#
#      SaleType SaleCondition SalePrice   House  TotalUsableArea  \
# ...

# %% [markdown]
# ### Bar Plot

# %%
corr=data.corr(numeric_only=True)['SalePrice'].sort_values(ascending=False)
plt.figure(figsize=(10,6))
sns.barplot(x=corr.head(5),y=corr.head(5).index,palette='viridis')
plt.title('Top Features Correlated with SalePrice')
plt.xlabel('Correlation Coefficient')
plt.ylabel('Counts')
plt.show()

## Insights
#>> We clearly shows that more saleprice with respect to more Correlation Coefficient.
# Out:
# C:\Users\DHRUV PATEL\AppData\Local\Temp\ipykernel_13424\1206704597.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=corr.head(5),y=corr.head(5).index,palette='viridis')

# %% [markdown]
# ### Scatter Plot

# %%
plt.figure(figsize=(8,5))
plt.scatter(data['OverallQual'],data['TotalUsableArea'],c=data['SalePrice'],cmap='viridis')
plt.colorbar(label='Sale Price')
plt.xlabel('Overall Quality')
plt.ylabel('Total Usable Area')
plt.title('Overall Quality vs Total Usable Area (Colored by Sale Price)')
plt.show()

# Insights scatter plot shows that Total Usable Area and Overall Quality have a positive linear relationship.
# we have see that area and quality increase ,the sale price also tends to increase.
# however , few outliers detected.

# %% [markdown]
# ### Box Plot

# %%
sns.boxplot(x=data['PricePerTotalSqrFt'])
plt.title('Boxplot of Price Per Total Square Foot')
plt.xlabel('Price Per Sqft')
plt.show()

# %%
corre=data.corr(numeric_only=True)
top_corre=corre['SalePrice'].sort_values(ascending=False)
print(top_corre)
# Out:
# SalePrice             1.000000
# House                 0.992236
# TotalUsableArea       0.807518
# OverallQual           0.790982
# GrLivArea             0.708624
# PricePerTotalSqrFt    0.661488
# GarageCars            0.640409
# GarageArea            0.623431
# TotalBsmtSF           0.613581
# 1stFlrSF              0.605852
# FullBath              0.560664
# TotRmsAbvGrd          0.533723
# YearBuilt             0.522897
# YearRemodAdd          0.507101
# GarageYrBlt           0.486362
# MasVnrArea            0.472614
# Fireplaces            0.466929
# BsmtFinSF1            0.386420
# WoodDeckSF            0.324413
# 2ndFlrSF              0.319334
# OpenPorchSF           0.315856
# HalfBath              0.284108
# LotArea               0.263843
# BsmtFullBath          0.227122
# BsmtUnfSF             0.214479
# LotFrontage           0.209624
# BedroomAbvGr          0.168213
# ScreenPorch           0.111447
# PoolArea              0.092404
# 3SsnPorch             0.044584
# ...

# %%
data['HasFirePlace']=data['Fireplaces'].apply(lambda x:1 if x>0 else 0)

plt.figure(figsize=(7,5))
sns.boxplot(x='HasFirePlace',y='SalePrice',data=data)
plt.title('Impact of Fireplace on SalePrice')
plt.xticks([0,1],['No Fireplace','Has Fireplace'])
plt.xlabel('Fireplace')
plt.ylabel('SalePrice')
plt.tight_layout()
plt.show()

# Insight
# We have clearly shows that has fireplace is more saleprice than no fireplace.

# %%
data['HasPool']=data['PoolArea'].apply(lambda x:1 if x>0 else 0)

# %%
data['HasGarage']=data['GarageArea'].apply(lambda x: 1 if x > 0 else 0)

# %%
amenties=['HasPool','HasGarage','HasFirePlace']
for amenity in amenties:
    print(f"\n {amenity} Effect on SalePrice:")
    print(data.groupby(amenity)['SalePrice'].describe()[['mean','count']])
# Out:
#  HasPool Effect on SalePrice:
#                   mean   count
# HasPool
# 0        180404.663455  1453.0
# 1        288138.571429     7.0
#
#  HasGarage Effect on SalePrice:
#                     mean   count
# HasGarage
# 0          103317.283951    81.0
# 1          185479.511240  1379.0
#
#  HasFirePlace Effect on SalePrice:
#                        mean  count
# HasFirePlace
# 0             141331.482609  690.0
# 1             216397.692208  770.0
